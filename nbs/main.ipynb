# %%
# | default_exp main

# %%
from Multi_alphabet_Text_Recognition.custom_dataset import CustomDataset, display_random_images

# %%
train_arab_dataset_1 = CustomDataset(targ_dir='../../datasets/overall/arab/test/1/', dataset='arab')
train_arab_dataset_2 = CustomDataset(targ_dir='../../datasets/overall/arab/test/2/', dataset='arab')

display_random_images(dataset=train_arab_dataset_1)
display_random_images(dataset=train_arab_dataset_2)
# Out:
# الدولة
# ماستركارد
# سلامتكم
# أمانا

# %%
english_dataset = CustomDataset(targ_dir='../../datasets/korean/KAIST/English/Mobile_Phone', dataset='korean')
display_random_images(dataset=english_dataset)
# Out:
# LabMembers
# ROSE

# %%
korean_dataset = CustomDataset(targ_dir='../../datasets/korean/KAIST/Korean/Mobile_Phone', dataset='korean')
display_random_images(dataset=korean_dataset)
# Out:
# 어이집린
# 혁
